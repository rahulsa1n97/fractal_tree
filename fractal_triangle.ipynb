# %%
import pandas as pd
import matplotlib.pyplot as plt 
import random as rd
import numpy as np

# %%
def mid(x,y):
    mp=[0,0]
    mp[0]=(x[0]+y[0])/2
    mp[1]=(x[1]+y[1])/2
    return mp

# %%
p1=[300,100]
p2=[200,300]
p3=[400,300]
sp=[100,150]

# %%
plt.scatter(p1[0],p1[1])
plt.scatter(p2[0],p2[1])
plt.scatter(p3[0],p3[1])
plt.scatter(sp[0],sp[1])

# %%
for i in range(3000):
    random_num=rd.choice([p1,p2,p3])
    mid_point=mid(cp,random_num)
    plt.scatter(mid_point[0],mid_point[1],s=5)
    cp=mid_point
plt.show()
